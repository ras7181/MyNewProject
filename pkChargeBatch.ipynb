# %%
import pandas as pd

# %%
pkChargeBatch = pd.read_csv("pkChargeBatch.csv", header=None)
pkChargeBatch.head(10)
# Out:
#           0                      1             2             3        4
# 0      Date                   Dept  Batch Number  Transactions  Charges
# 1  1/1/2020           Peds Allergy           NaN           NaN      NaN
# 2  1/1/2020               Peds BMT           NaN           NaN      NaN
# 3  1/1/2020        Peds Cardiology           NaN           NaN      NaN
# 4  1/1/2020                Peds CC           NaN           NaN      NaN
# 5  1/1/2020           Peds Endo DM           NaN           NaN      NaN
# 6  1/1/2020     Peds Endocrinology           NaN           NaN      NaN
# 7  1/1/2020  Peds Gastroenterology           NaN           NaN      NaN
# 8  1/1/2020            Peds HemOnc           NaN           NaN      NaN
# 9  1/1/2020      Peds Hospitalists           NaN           NaN      NaN
